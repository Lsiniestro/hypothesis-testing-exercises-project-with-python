# %% [markdown]
# # Problemas de prueba de hipótesis

# %% [markdown]
# ## Ejercicio 1
#
# Usted es un nutricionista que investiga dos tipos diferentes de dietas para ver si existe una diferencia significativa en la pérdida de peso después de un mes. Eliges dos grupos aleatorios de personas; un grupo sigue la primera dieta y el otro sigue la segunda. Al final del mes, se registra la pérdida de peso (en kg) de cada persona:
#
# | Diet 1 | Diet 2 |
# |:-------|:-------|
# | 2.0 | 3.0 |
# | 2.5 | 3.2 |
# | 3.0 | 3.1 |
# | 2.8 | 2.9 |
# | 2.3 | 2.8 |
# | 2.7 | 3.0 |
# | 2.5 | 3.2 |
#
# Con estos datos se busca responder a la siguiente pregunta: ¿Existe una diferencia significativa en la pérdida de peso promedio entre las personas que siguieron la primera dieta y las que siguieron la segunda dieta?
#
# Para sacar conclusiones, siga los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba para comprobar la hipótesis. Puede utilizar la prueba t de Student.
# -Analizar las conclusiones.

# %%
# TODO
import numpy as np
import scipy.stats as stats


dieta1=[2.0,2.5,3.0,2.8,2.3,2.7,2.5]
dieta2=[3.0,3.2,3.1,2.9,2.8,3.0,3.2]

media_dieta1= np.asarray(dieta1).mean()
media_dieta2= np.asarray(dieta2).mean()

print('La H0 es: No hay diferencia entre las dietas')
print(f'La H1 es: la media de perdida de peso para la dieta 1 es: {media_dieta1.round(2)} y para la dieta 2 es: {media_dieta2.round(2)}. Hay diferencia')

t_test= stats.ttest_ind(dieta1, dieta2)

t_test
print('Valor T-test: ',t_test[0])
print('Valor P-value: ',t_test[1])

print('El valor de P-value es menor al del valor de significancia (0.05), por lo tanto  se rechaza la hipotesis nula y se acepta la alternativa')
# Out:
# La H0 es: No hay diferencia entre las dietas
# La H1 es: la media de perdida de peso para la dieta 1 es: 2.54 y para la dieta 2 es: 3.03. Hay diferencia
# Valor T-test:  -3.5383407969933938
# Valor P-value:  0.004083270191713912
# El valor de P-value es menor al del valor de significancia (0.05), por lo tanto  se rechaza la hipotesis nula y se acepta la alternativa

# %% [markdown]
# ## ANOVA
#
# **ANOVA** (*Analysis of Variance - Análisis de variación*) Es una técnica estadística utilizada para comparar las medidas de dos o más grupos. La idea detrás de ANOVA es descomponer la variabilidad total de los datos en dos componentes: variabilidad entre grupos y variabilidad dentro de los grupos:
#
# - **Variabilidad entre grupos**: Esta variabilidad se refiere a las diferencias entre las medias del grupo. Si esta variabilidad es considerablemente mayor que la variabilidad dentro del grupo, podría ser una indicación de que al menos una de las medias del grupo es diferente.
# - **Variabilidad dentro del grupo**: Esta variabilidad se refiere a la dispersión de los datos dentro de cada grupo. Si todos los grupos tienen una variabilidad similar, entonces cualquier diferencia notable en las medias de los grupos podría considerarse significativa.
#
# Las hipótesis en ANOVA suelen incluir:
#
# - **Hipótesis nula** ($H₀$): Las medias de todos los grupos son iguales.
# - **Hipótesis alternativa** ($H₁$): Al menos una de las medias del grupo es diferente.
#
# Si el resultado de la prueba ANOVA es significativo (por ejemplo, un valor p inferior a un umbral como 0,05), esto sugiere que al menos la media de un grupo es diferente.

# %% [markdown]
# ## Ejercicio 2
#
# Un agricultor decide probar tres tipos diferentes de fertilizantes para determinar si alguno es superior en términos de producción de maíz. El agricultor planta maíz en 15 parcelas idénticas y utiliza los tres fertilizantes (5 parcelas para cada tipo). Al final de la temporada mide el rendimiento de maíz (en kg) de cada parcela, con el siguiente resultado:
#
# | Fertilizante 1 | Fertilizante 2 | Fertilizante 3 |
# |:-------------|:-------------|:-------------|
# | 20 | 22 | 24 |
# | 21 | 21 | 23 |
# | 20 | 23 | 22 |
# | 19 | 22 | 23 |
# | 20 | 21 | 24 |
#
# Con estos datos busca responder la siguiente pregunta: ¿Existe una diferencia significativa en el rendimiento promedio del maíz entre los tres tipos de fertilizantes?
#
# Para ayudarte, sigue los siguientes puntos:
#
# -Enunciar la hipótesis: hipótesis nula y alternativa.
# -Realizar la prueba ANOVA.
# -Analizar las conclusiones.
# -Si un fertilizante es mejor que otro, ¿cómo podemos saberlo?

# %%
# TODO
import numpy as np
import pandas as pd
# import statsmodels sm,ols and pairwise_tukeyhsd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import pairwise_tukeyhsd

print('La hipotesis nula es: todos los fertilizantes son iguales')
print('La hipotesis altenativa es: uno es mejor que los otros')

fertilizante1= [20,21,20,19,20]
fertilizante2=[22,21,23,22,21]
fertilizante3=[24,23,22,23,24]

df = pd.DataFrame({'fertilizante' : ['1']*5 + ['2']*5 + ['3']*5,'pesos_Kg' : np.concatenate((fertilizante1,fertilizante2, fertilizante3),axis=0)})

# create a model with statsmodels ols and fit data into the model
model = ols(formula='pesos_Kg ~ fertilizante', data=df).fit()

# call statsmodels stats.anova_lm and pass model as an argument to perform ANOVA
anova_result = sm.stats.anova_lm(model, type=2)

print(anova_result)
# print output
print('')
print('F-value =',anova_result.iat[0,3])
print('P-value=',anova_result.iat[0,4].round(5),' se puede observar que es menor al valor de significancia y se rechaza la hipotesis nula')
# Out:
# La hipotesis nula es: todos los fertilizantes son iguales
# La hipotesis altenativa es: uno es mejor que los otros
#                 df     sum_sq    mean_sq          F   PR(>F)
# fertilizante   2.0  25.733333  12.866667  20.315789  0.00014
# Residual      12.0   7.600000   0.633333        NaN      NaN
#
# F-value = 20.315789473684216
# P-value= 0.00014  se puede observar que es menor al valor de significancia y se rechaza la hipotesis nula

# %%
multiple_comp_result = pairwise_tukeyhsd(endog=df['pesos_Kg'],groups=df['fertilizante'], alpha=0.05)
print(multiple_comp_result.summary())

print('En la columna "reject" nos indica si hay diferencia mayor al valor de sigificancia. El orden de mejor a peor de los fertilizantes lo obtenemos de comparar la columna "meandiff"')
print('El mejor fertilizante es el 3 seguido por el 2')
# Out:
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ...
# group1 group2 meandiff p-adj  lower  upper  reject
# --------------------------------------------------
#      1      2      1.8 0.0099 0.4572 3.1428   True
#      1      3      3.2 0.0001 1.8572 4.5428   True
#      2      3      1.4 0.0409 0.0572 2.7428   True
# --------------------------------------------------
# En la columna "reject" nos indica si hay diferencia mayor al valor de sigificancia. El orden de mejor a peor de los fertilizantes lo obtenemos de comparar la columna "meandiff"
# El mejor fertilizante es el 3 seguido por el 2
